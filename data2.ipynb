# %%
def add(x,y):
    return x+y


def add(x,y):
    return x+y

def add(x,y):
    return x+y

def add(x,y):
    return x+y

def add(x,y):
    return x+y



def add(x,y):
    return x+y


def add(x,y):
    return x+y

# %%
a = 5
b = 10
result = add(a, b)
